# %%
n = ...
c1 = ...
c2 = ...
e = 3

# %%
R.<x,y> = PolynomialRing(ZZ)

# %%
f1 = x^3 - c1
f2 = (x+y)^3 - c2

# %%
fy = f2.polynomial(x).resultant(f1.polynomial(x))

# %%
print(fy)
fyzm = fy.change_ring(Zmod(n))
# Out:
# -y^9 - ...*y^6 - ...*y^3 - ...

# %%
f = fyzm.monic()
print(f)
# Out:
# y^9 + ...*y^6 + ...*y^3 + ...

# %%
salt = f.small_roots(X=2^110, beta=0.5)[0]
print(salt)
# Out:
# 1703955957865607562938382370516

# %%
from Cryptodome.Util.number import bytes_to_long, long_to_bytes
m = salt*(c2+2*c1-salt^3) / (c2 - c1 + 2*salt^3) % n

# %%
long_to_bytes(m)
# Out:
# b'\xfb?d\xd9\x91\xb9\xd9)\xe7\x98\xe0\x8f\x11\xd0\xd5G\xe0Z\xdd$\xe3\x1fV<\x96\x04\xca\xb1e]w\x8c\xed\xf8\xb6\xec\x03\xf1zZ\xfe\xff\xf316\xb4\xd0\xa2\xee\x05$\xb5\xdd6p\xe4XB\xa1\xe0\x12\xb4\xa5\'\x01\x10j\xe2}\xf0\xb4K\xb3\x87\xd50\xfa\xdc\x08\x04\xee\x1ft\x1c\xe1%2\xd58\xa2\xc3+-\xb1\x95_\'3XU\xc9\x82{ky\xae\xc1Q\xf9\x84\xf7\xe7\xf7Ih-\x87\xb1\x84c\xd6Q+\xbcF\xfa\xd32"\x04\x90RH\xe4^\x16k<n\xe2\xf0\x81\x0f\xd5\x9c\t\x0e\xb5\x03P\x82t\xed/\x99\x16\x1a\x8e\x1b\xd7\xcfp\x83-\xb2\xcd\xcb-D\x89\r\x14\xfc\xc8\xd9yPQp\x96\x1aNW\xcb\x14\xd45\xe7\x7f\r\x95\x019QsK\x0f\x95\xa0\xc6o\xd7\xdd[\xbbG\x14\xc4\r\xe30ops{n0w_you_4re_a_coppersmiths_ma5ter}'

# %%
n = ...
a = ...
b = ...
c = ...

# %%
pow(b,n,n^2)
# Out:
# ...

# %%
pow(b,n,n^2) % n
# Out:
# ...

# %%
x = power_mod(b,n,n^2)
print(x)
inverse_mod(x, n^2)
# Out:
# ...
# ...

# %%
type(x)
# Out:
# <class 'sage.rings.finite_rings.integer_mod.IntegerMod_gmp'>

# %%
pow
# Out:
# ...
